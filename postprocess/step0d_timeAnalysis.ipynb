# %% [markdown]
# # Run time analysis

# %%
pinsga2_runtimes = [250.66257667541504, 264.79734110832214, 285.3773956298828, 282.18343925476074, 294.491250038147, 272.0306577682495, 291.38520860671997, 293.0256521701813, 302.2948544025421, 287.57715010643005, 289.92734718322754, 299.3334012031555, 298.2682235240936, 291.5534453392029, 292.4516615867615, 301.95196557044983, 318.32254123687744, 298.14620327949524, 287.29378366470337, 280.23397040367126, 298.80610156059265, 280.26338934898376, 293.4250535964966, 296.8519525527954, 301.7770299911499, 302.71295523643494, 308.39494013786316, 295.30012464523315, 292.23187923431396, 295.45615100860596]

nsga2_runtimes = [363.71441864967346, 371.236759185791, 377.16073870658875, 378.6721272468567, 378.7819609642029, 379.56066846847534, 381.51104283332825, 381.2453269958496, 383.9930408000946, 381.38296127319336, 382.3978555202484, 381.0062828063965, 379.7199833393097, 382.108252286911, 384.9768707752228, 385.8956730365753, 385.5235667228699, 382.52680110931396, 384.7919235229492, 380.50717401504517, 385.28613352775574, 384.6736512184143, 387.0600941181183, 386.42108726501465, 386.4492697715759, 390.69462156295776, 386.86059165000916, 385.322731256485, 386.54839992523193, 386.4048044681549]

# %% [markdown]
# ## Violin plots

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, axs = plt.subplots(figsize=(5, 5))

data = np.array([pinsga2_runtimes, nsga2_runtimes]).T

axs.violinplot(data, showmeans=False, showmedians=True)
axs.set_title("Algorithm time trials for 1989")

axs.set_xticks([1,2], labels=["PI-NSGA-II", "NSGA-II"])

axs.yaxis.grid(True)

axs.set_ylabel("Run Time (seconds)")
axs.set_xlabel("Algorithm")
# Out:
# Text(0.5, 0, 'Algorithm')

# %% [markdown]
# ## Save figure

# %%
plt.savefig("runtimes.eps", format="eps")

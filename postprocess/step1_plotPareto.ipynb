# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import pickle

year = 2000
file_name = '../master_run_record.pkl'

infile = open(file_name, 'rb')
tab = pickle.load(infile)

x = tab[selection_mask]['irr_total']
y = tab[selection_mask]['yield']

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(x, y)

ax.set_xlabel('Total irrigation')
ax.set_ylabel('Yield')

plt.title(year)
plt.show()

# %%
import pandas as pd

# This space is made for looking and playing with results

tab = pd.read_pickle("/rdata/ian/pico/paperRuns/finalRuns/global_run_table.pkl")

tab[tab["algorithm"] == "nsga2"]["run"]
